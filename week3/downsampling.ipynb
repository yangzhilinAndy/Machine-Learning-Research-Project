# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
train_df=pd.read_csv('/Users/zhilinyang/Desktop/x_train.csv')
train_df.head()
# Out:
#   Unnamed: 0  smart_1_normalized   smart_1_raw  smart_3_normalized  \
# 0   Z305Q0MX          115.906013  1.329576e+08           91.167076
# 1   Z305D6MG          114.579772  1.211792e+08           94.009118
# 2   Z304GJ8Z          115.105291  1.178986e+08           92.000000
# 3   Z300WJWN          115.815340  1.276666e+08           92.000000
# 4   Z3029B3B          114.793688  1.187385e+08           95.000802
#
#    smart_4_raw  smart_5_raw  smart_7_normalized   smart_7_raw  \
# 0     8.889620          0.0           87.310915  6.504494e+08
# 1     5.995798          0.0           87.839517  7.355420e+08
# 2     9.000000          0.0           88.171075  7.734591e+08
# 3    17.495410          0.0           89.962731  5.272009e+09
# 4     4.999709          0.0           81.161219  5.015784e+08
#
#    smart_9_normalized   smart_9_raw      ...        smart_190_raw  \
# 0           83.181576  15178.591383      ...            25.711848
# ...

# %%
y_train.sum()
# Out:
# 1    458.0
# dtype: float64

# %%
y_train=pd.read_csv('/Users/zhilinyang/Desktop/y_train.csv',header=None)
y_train=y_train.iloc[:,1:]

# %%
healthy_sample_list=y_train[y_train==0]
healthy_sample_list=healthy_sample_list.dropna().index
healthy_sample=train_df.reindex(healthy_sample_list)

# %%
healthy_sample.index
# Out:
# Int64Index([    0,     1,     2,     3,     4,     5,     6,     8,     9,
#                10,
#             ...
#             14990, 14991, 14992, 14993, 14994, 14995, 14996, 14997, 14998,
#             14999],
#            dtype='int64', length=14543)

# %%
len(healthy_sample)
# Out:
# 14543

# %%
healthy_sample=healthy_sample.iloc[:,1:]
healthy_sample.head()
# Out:
#    smart_1_normalized   smart_1_raw  smart_3_normalized  smart_4_raw  \
# 0          115.906013  1.329576e+08           91.167076     8.889620
# 1          114.579772  1.211792e+08           94.009118     5.995798
# 2          115.105291  1.178986e+08           92.000000     9.000000
# 3          115.815340  1.276666e+08           92.000000    17.495410
# 4          114.793688  1.187385e+08           95.000802     4.999709
#
#    smart_5_raw  smart_7_normalized   smart_7_raw  smart_9_normalized  \
# 0          0.0           87.310915  6.504494e+08           83.181576
# 1          0.0           87.839517  7.355420e+08           82.823755
# 2          0.0           88.171075  7.734591e+08           80.170393
# 3          0.0           89.962731  5.272009e+09           61.186567
# 4          0.0           81.161219  5.015784e+08           72.144316
#
#     smart_9_raw  smart_12_raw      ...        smart_190_raw  \
# 0  15178.591383      8.889620      ...            25.711848
# ...

# %%
k_means=KMeans(n_clusters=100,n_init=10,max_iter=300,tol=1e-04,random_state=0)
dist=k_means.fit_transform(healthy_sample)
x_dist=pd.DataFrame(dist)
x_dist.head()
# Out:
#              0             1             2             3             4   \
# 0  1.118461e+11  2.733106e+14  7.997142e+09  2.044301e+11  2.855057e+11
# 1  1.007069e+11  2.733105e+14  1.266590e+10  1.927761e+11  2.737887e+11
# 2  1.231524e+11  2.733105e+14  9.876945e+09  2.151831e+11  2.961700e+11
# 3  2.147301e+10  2.733060e+14  9.275151e+10  1.131117e+11  1.941449e+11
# 4  3.345579e+10  2.733108e+14  1.464036e+11  5.966161e+10  1.406604e+11
#
#              5             6             7             8             9   \
# 0  6.147301e+10  1.734777e+11  3.411706e+10  2.933960e+10  2.469960e+11
# 1  5.122233e+10  1.620613e+11  4.703000e+10  1.653236e+10  2.427603e+11
# 2  7.338922e+10  1.845089e+11  3.284648e+10  3.583898e+10  2.512846e+11
# 3  3.180174e+10  8.220137e+10  1.204542e+11  6.984004e+10  2.236327e+11
# 4  8.427696e+10  2.833711e+10  1.731043e+11  1.229253e+11  2.339724e+11
#
#        ...                 90            91            92            93  \
# ...

# %%
x_dist.head()
# Out:
#              0             1             2             3             4   \
# 0  1.118461e+11  2.733106e+14  7.997142e+09  2.044301e+11  2.855057e+11
# 1  1.007069e+11  2.733105e+14  1.266590e+10  1.927761e+11  2.737887e+11
# 2  1.231524e+11  2.733105e+14  9.876945e+09  2.151831e+11  2.961700e+11
# 3  2.147301e+10  2.733060e+14  9.275151e+10  1.131117e+11  1.941449e+11
# 4  3.345579e+10  2.733108e+14  1.464036e+11  5.966161e+10  1.406604e+11
#
#              5             6             7             8             9   \
# 0  6.147301e+10  1.734777e+11  3.411706e+10  2.933960e+10  2.469960e+11
# 1  5.122233e+10  1.620613e+11  4.703000e+10  1.653236e+10  2.427603e+11
# 2  7.338922e+10  1.845089e+11  3.284648e+10  3.583898e+10  2.512846e+11
# 3  3.180174e+10  8.220137e+10  1.204542e+11  6.984004e+10  2.236327e+11
# 4  8.427696e+10  2.833711e+10  1.731043e+11  1.229253e+11  2.339724e+11
#
#        ...                 90            91            92            93  \
# ...

# %%
down_sample=np.array([])
for center in range(0,100):
    arrange=x_dist.sort_values(by=[center])
    down_sample=np.append(down_sample,arrange[center].index.values[:10])
down_sample
# Out:
# array([  5.72700000e+03,   4.52100000e+03,   1.34870000e+04,
#          8.62000000e+03,   7.00800000e+03,   6.12400000e+03,
#          4.37100000e+03,   1.49000000e+03,   4.88800000e+03,
#          8.80200000e+03,   6.21100000e+03,   6.31900000e+03,
#          1.31150000e+04,   7.92600000e+03,   1.00370000e+04,
#          1.23660000e+04,   5.28100000e+03,   1.00830000e+04,
#          7.71300000e+03,   9.99700000e+03,   6.49900000e+03,
#          4.90100000e+03,   5.85100000e+03,   4.11900000e+03,
#          4.54000000e+03,   1.11250000e+04,   8.25300000e+03,
#          4.66600000e+03,   1.13040000e+04,   4.68300000e+03,
#          5.59800000e+03,   1.31760000e+04,   1.33680000e+04,
#          1.00270000e+04,   1.09210000e+04,   8.52900000e+03,
#          1.37200000e+03,   1.03760000e+04,   5.91500000e+03,
#          1.15440000e+04,   4.36300000e+03,   1.19000000e+02,
#          1.31890000e+04,   1.36800000e+03,   5.54000000e+03,
# ...

# %%
len(down_sample)
# Out:
# 1000

# %%
healthy_sample.head()
# Out:
#    smart_1_normalized   smart_1_raw  smart_3_normalized  smart_4_raw  \
# 0          115.906013  1.329576e+08           91.167076     8.889620
# 1          114.579772  1.211792e+08           94.009118     5.995798
# 2          115.105291  1.178986e+08           92.000000     9.000000
# 3          115.815340  1.276666e+08           92.000000    17.495410
# 4          114.793688  1.187385e+08           95.000802     4.999709
#
#    smart_5_raw  smart_7_normalized   smart_7_raw  smart_9_normalized  \
# 0          0.0           87.310915  6.504494e+08           83.181576
# 1          0.0           87.839517  7.355420e+08           82.823755
# 2          0.0           88.171075  7.734591e+08           80.170393
# 3          0.0           89.962731  5.272009e+09           61.186567
# 4          0.0           81.161219  5.015784e+08           72.144316
#
#     smart_9_raw  smart_12_raw      ...        smart_190_raw  \
# 0  15178.591383      8.889620      ...            25.711848
# ...

# %%
train_x=healthy_sample.iloc[down_sample]
len(train_x)
# Out:
# 1000

# %% [markdown]
# 1000 healthy sample vs 458 failed sample

# %%
fail_sample=fail_sample.iloc[:,1:]
fail_sample.head()
# Out:
#      smart_1_normalized   smart_1_raw  smart_3_normalized  smart_4_raw  \
# 7            114.267312  1.104446e+08             92.0000    15.000000
# 65           114.432353  1.210992e+08             96.0000     4.000000
# 96           113.899670  9.405655e+07             98.0000     2.000000
# 106          114.516903  1.077208e+08             96.0000     4.000000
# 213          114.361683  1.089934e+08             93.0452     6.968235
#
#      smart_5_raw  smart_7_normalized   smart_7_raw  smart_9_normalized  \
# 7       0.000000           78.614655  8.750762e+07           64.161279
# 65      0.000000           86.583803  4.800644e+08           86.614295
# 96      0.000000           87.000000  5.171410e+08           89.360995
# 106   899.555556           89.000000  8.555661e+08           77.540200
# 213     0.000000           86.845851  5.070397e+08           86.160590
#
#       smart_9_raw  smart_12_raw      ...        smart_190_raw  \
# ...

# %%
fail_sample_list=y_train[y_train==1]
fail_sample_list=fail_sample_list.dropna().index
fail_sample=train_df.reindex(fail_sample_list)
len(fail_sample)
# Out:
# 458

# %%
train_x.head()
# Out:
#        smart_1_normalized   smart_1_raw  smart_3_normalized  smart_4_raw  \
# 5900           114.988032  1.177480e+08           91.000000    12.692330
# 4649           113.936922  1.108084e+08           91.000000    19.692330
# 13900          115.776090  1.291434e+08           94.694397     5.376937
# 8882           115.147045  1.241766e+08           91.086802    15.692330
# 7225           114.577577  1.136608e+08           94.694397     5.376937
#
#        smart_5_raw  smart_7_normalized   smart_7_raw  smart_9_normalized  \
# 5900           0.0           88.982286  9.008683e+08           78.708807
# 4649           0.0           88.979787  8.956278e+08           78.718271
# 13900          0.0           79.777837  4.413162e+08           71.077120
# 8882           0.0           88.979331  8.944433e+08           78.718271
# 7225           0.0           79.709331  4.302224e+08           71.077120
#
#         smart_9_raw  smart_12_raw      ...        smart_190_raw  \
# ...

# %%
train_x=train_x.append(fail_sample)
train_x.shape
# Out:
# (1458, 25)

# %%
train_x.to_csv(path_or_buf='/Users/zhilinyang/Desktop/down_train_x.csv')
